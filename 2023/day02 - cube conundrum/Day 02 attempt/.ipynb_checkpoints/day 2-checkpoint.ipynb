# %%
import re

# %%
with open('input.txt', 'r') as file:
    data = file.readlines()

# %%
data
# Out:
# ['Game 1: 1 green, 1 blue, 1 red; 1 green, 8 red, 7 blue; 6 blue, 10 red; 4 red, 9 blue, 2 green; 1 green, 3 blue; 4 red, 1 green, 10 blue\n',
#  'Game 2: 9 red, 7 green, 3 blue; 15 green, 2 blue, 5 red; 10 red, 3 blue, 13 green\n',
#  'Game 3: 3 red, 1 blue, 4 green; 6 red, 3 green, 2 blue; 6 red, 16 blue, 1 green\n',
#  'Game 4: 2 blue, 2 green, 19 red; 3 blue, 11 red, 16 green; 18 blue, 13 green, 20 red; 18 red, 12 blue, 16 green; 8 green, 16 blue, 16 red\n',
#  'Game 5: 8 green, 1 red, 12 blue; 10 green, 6 red, 13 blue; 1 red, 3 blue, 6 green; 14 blue, 2 red, 7 green\n',
#  'Game 6: 1 red; 1 blue; 2 green, 1 blue; 1 red, 3 blue; 1 red, 2 blue, 2 green; 1 green, 7 blue, 1 red\n',
#  'Game 7: 2 red, 1 blue, 5 green; 5 green, 1 red; 3 red, 7 blue; 8 blue, 1 red, 4 green\n',
#  'Game 8: 6 green, 4 blue; 10 green, 7 blue; 5 blue; 1 red, 7 blue; 11 green, 1 red\n',
# ...

# %%
limits = {
    'red': 12,
    'green': 13,
    'blue': 14
}

# %%
def get_game_id(line):
    game = re.findall(r'Game (\d+)', d)
    return game

# %%
def get_rgb(line, color):
    game = line.split(':')[1].strip().split(";")
    green = [re.findall(f'(\d+)\s+{color}', g) for g in game]  
    green = [int(g[0]) for g in green if len(g) > 0]
    data = []
    for g in green:
        if g > limits[color]:
            data.append('break')
    
    return 'break' not in data

# %%
colors = ['red', 'blue', 'green']

total = 0
for d in data:
    check = []
    for color in colors:
        check.append(get_rgb(d, color))
    if False not in check:
        game_no = int(get_game_id(d)[0])
        print(f'Game {game_no} Valid')
        total += game_no
# Out:
# Game 1 Valid
# Game 5 Valid
# Game 6 Valid
# Game 7 Valid
# Game 8 Valid
# Game 9 Valid
# Game 10 Valid
# Game 13 Valid
# Game 15 Valid
# Game 16 Valid
# Game 22 Valid
# Game 23 Valid
# Game 31 Valid
# Game 32 Valid
# Game 34 Valid
# Game 35 Valid
# Game 37 Valid
# Game 38 Valid
# Game 40 Valid
# Game 41 Valid
# Game 42 Valid
# Game 44 Valid
# Game 45 Valid
# Game 47 Valid
# Game 49 Valid
# Game 50 Valid
# Game 52 Valid
# Game 54 Valid
# Game 55 Valid
# Game 56 Valid
# Game 58 Valid
# Game 60 Valid
# Game 62 Valid
# Game 63 Valid
# Game 64 Valid
# Game 65 Valid
# Game 67 Valid
# Game 68 Valid
# Game 70 Valid
# Game 71 Valid
# Game 72 Valid
# Game 73 Valid
# Game 74 Valid
# Game 78 Valid
# Game 80 Valid
# Game 81 Valid
# Game 82 Valid
# Game 83 Valid
# Game 88 Valid
# Game 89 Valid
# Game 92 Valid
# Game 93 Valid
# Game 95 Valid
# Game 96 Valid
# Game 97 Valid
# Game 98 Valid
# Game 99 Valid

# %%
total
# Out:
# 3035

# %%
data
# Out:
# ['Game 1: 1 green, 1 blue, 1 red; 1 green, 8 red, 7 blue; 6 blue, 10 red; 4 red, 9 blue, 2 green; 1 green, 3 blue; 4 red, 1 green, 10 blue\n',
#  'Game 2: 9 red, 7 green, 3 blue; 15 green, 2 blue, 5 red; 10 red, 3 blue, 13 green\n',
#  'Game 3: 3 red, 1 blue, 4 green; 6 red, 3 green, 2 blue; 6 red, 16 blue, 1 green\n',
#  'Game 4: 2 blue, 2 green, 19 red; 3 blue, 11 red, 16 green; 18 blue, 13 green, 20 red; 18 red, 12 blue, 16 green; 8 green, 16 blue, 16 red\n',
#  'Game 5: 8 green, 1 red, 12 blue; 10 green, 6 red, 13 blue; 1 red, 3 blue, 6 green; 14 blue, 2 red, 7 green\n',
#  'Game 6: 1 red; 1 blue; 2 green, 1 blue; 1 red, 3 blue; 1 red, 2 blue, 2 green; 1 green, 7 blue, 1 red\n',
#  'Game 7: 2 red, 1 blue, 5 green; 5 green, 1 red; 3 red, 7 blue; 8 blue, 1 red, 4 green\n',
#  'Game 8: 6 green, 4 blue; 10 green, 7 blue; 5 blue; 1 red, 7 blue; 11 green, 1 red\n',
# ...
